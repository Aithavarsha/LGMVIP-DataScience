# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.22.4)

# %%
import cv2
photo = cv2.imread('/content/Minion.jpg')

# %%
import time
start = time.time()

# %%
gray = cv2.cvtColor(photo, cv2.COLOR_BGR2GRAY)
from google.colab.patches import cv2_imshow
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7FF905A4DE70>

# %%
invert = cv2.bitwise_not(gray)
cv2_imshow(invert)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7FF905A4E320>

# %%
blur = cv2.GaussianBlur(invert, (15, 15), 0)
cv2_imshow(blur)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7FF905A4F250>

# %%
invertblur = cv2.bitwise_not(blur)
cv2_imshow(invertblur)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7FF905A4DF60>

# %%
sketch = cv2.divide(gray, invertblur, scale= 250.0)
cv2_imshow(sketch)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7FF905A4ED40>

# %%
from google.colab.patches import cv2_imshow
cv2.imwrite('output.png', sketch)
# Out:
# True

# %%
end = time.time()
print(end-start)
# Out:
# 187.28568744659424
